# %%
import sys
# from optimized_registration_segmentation import fMRI_Segmentation
# from fMRI_Segmentation import fMRI_Segmentation
import glob
import numpy as np
import os
import warnings
warnings.filterwarnings("ignore")

# %%
from parallel_seg import fMRI_Segmentation

raw_path = '/snl/abcd/raw-data/fmri/baseline/rest/'
seg_smri = '/nadata/cnl/abcd/data/imaging/smri/interim/synthseg/baseline/'
save_path = '/cnl/abcd/data/imaging/fmri/rsfmri/interim/segmented/baseline/'
# save_path = '/cnl/abcd/test/seg'
subjects_list_path=''
# subjects_list_path='/home/acamassa/ABCD/todo2.txt'

# Create an instance of the fMRI_Segmentation class
fmri_segmentation = fMRI_Segmentation(raw_path, seg_smri, save_path,subjects_list_path)

# Call the segment_fmri method to start the segmentation process
error_log = fmri_segmentation.segment_fmri()
# fmri_segmentation.band_pass_filt_fmri()
# Check for any errors encountered during segmentation
# if error_log:
#     print("Segmentation encountered errors:", error_log)
# else:
#     print("Segmentation completed successfully.")
# Out:
# Full dataset ready with 30353 fMRI files and 11402 sMRI files.
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# ...

# %%
raw_path = '/snl/abcd/raw-data/fmri/baseline/rest/'
seg_smri = '/nadata/cnl/abcd/data/imaging/smri/interim/synthseg/baseline/'
save_path = '/cnl/abcd/data/imaging/fmri/rsfmri/interim/segmented/baseline/'
# subjects_list_path='/home/acamassa/ABCD/to_do2.txt'
subjects_list_path=''

fmri_seg=fMRI_Segmentation(raw_path,seg_smri,save_path,subjects_list_path)
try:
    # error=fmri_seg.segment_fmri()
    fmri_seg.band_pass_filt_fmri()
except:
    fmri_seg.band_pass_filt_fmri()
# np.savetxt('/home/acamassa/ABCD/rsfmri_Segerrors.txt', error, fmt='%s')
# Out:
# Full dataset ready with 28470 fMRI files and 11402 sMRI files.
# Filtered file already exists for sub-NDARINV0BAVEL0T, run: run-02
# Filtered file already exists for sub-NDARINV0BAVEL0T, run: run-03
# Filtered file already exists for sub-NDARINV0BAVEL0T, run: run-01
# Filtered file already exists for sub-NDARINV0BAVEL0T, run: run-04
# Filtered file already exists for sub-NDARINV0N10CEEL, run: run-01
# Filtered file already exists for sub-NDARINV0N10CEEL, run: run-02
# Filtered file already exists for sub-NDARINV0N10CEEL, run: run-03
# Filtered file already exists for sub-NDARINV0N10CEEL, run: run-04
# Filtered file already exists for sub-NDARINV00U4FTRU, run: run-01
# Filtered file already exists for sub-NDARINV00U4FTRU, run: run-02
# Filtered file already exists for sub-NDARINV00U4FTRU, run: run-03
# Filtered file already exists for sub-NDARINV00U4FTRU, run: run-04
# Filtered file already exists for sub-NDARINV0VXEC29A, run: run-01
# ...

# %%
fmri_seg.band_pass_filt_fmri()

# %%
import sys
from fMRI_Segmentation import fMRI_Segmentation
import glob
import numpy as np
import os
import warnings
warnings.filterwarnings("ignore")

raw_path = '/snl/abcd/raw-data/fmri/baseline/nback/'
seg_smri = '/nadata/cnl/abcd/data/imaging/smri/interim/synthseg/baseline/'
save_path = '/cnl/abcd/data/imaging/fmri/nback/interim/segmented/baseline/'
subjects_list_path='/home/acamassa/ABCD/abcd-taskfMRI/notebooks/FC/nback_subjects.txt'

fmri_seg=fMRI_Segmentation(raw_path,seg_smri,save_path,subjects_list_path)
error=fmri_seg.segment_fmri()
np.savetxt('/home/acamassa/ABCD/task_Segerrors.txt', error, fmt='%s')

# %%
# # # raw rs fMRI to segment data path
# raw_path = '/snl/abcd/raw-data/fmri/baseline/rest/'
# raw_path = '/snl/abcd/raw-data/fmri/2YearFollowUp/rest/downloads/'
raw_path = '/snl/abcd/raw-data/fmri/baseline/nback/'
# raw_path = '/snl/abcd/raw-data/fmri/baseline/SST/'

# # segmented sMRI data path 
seg_smri = '/nadata/cnl/abcd/data/imaging/smri/interim/synthseg/baseline/'
# seg_smri = '/cnl/abcd/data/imaging/smri/interim/synthseg/year2/'

# # where to save processed fMRI data
# save_path = '/cnl/abcd/data/imaging/fmri/rsfmri/interim/segmented/baseline/'
# save_path = '/cnl/abcd/data/imaging/fmri/rsfmri/interim/segmented/year2/'
# save_path = '/cnl/abcd/data/imaging/fmri/SST/interim/segmented/baseline/'
save_path = '/cnl/abcd/data/imaging/fmri/nback/interim/segmented/baseline/'

# subjects_list_path='/nadata/cnl/abcd/data/labels/baseline_depr_guids.txt'
# subjects_list_path='/nadata/cnl/abcd/data/labels/year2_depr_guids.txt'
subjects_list_path='/home/acamassa/ABCD/abcd-taskfMRI/notebooks/FC/nback_subjects.txt'
# subjects_list_path='/nadata/cnl/home/acamassa/ABCD/EDM/Notebooks/Humans/rs_subjects.txt'

# %%
fmri_seg=fMRI_Segmentation(raw_path,seg_smri,save_path,subjects_list_path)

# %%
# # segment: obtain one time series for each ROI
error=fmri_seg.segment_fmri()
# Out:
# segmenting  sub-NDARINV3TT997HJ 280
# /snl/abcd/raw-data/fmri/baseline/nback/sub-NDARINV3TT997HJ/ses-baselineYear1Arm1/func/sub-NDARINV3TT997HJ_ses-baselineYear1Arm1_task-nback_run-01_bold.nii
# no confounds file
# segmenting  sub-NDARINV4C2YD3TH 343
# /snl/abcd/raw-data/fmri/baseline/nback/sub-NDARINV4C2YD3TH/ses-baselineYear1Arm1/func/sub-NDARINV4C2YD3TH_ses-baselineYear1Arm1_task-nback_run-01_bold.nii
# missing ROIs!
# segmenting  sub-NDARINV4C2YD3TH 344
# /snl/abcd/raw-data/fmri/baseline/nback/sub-NDARINV4C2YD3TH/ses-baselineYear1Arm1/func/sub-NDARINV4C2YD3TH_ses-baselineYear1Arm1_task-nback_run-02_bold.nii
# missing ROIs!
# segmenting  sub-NDARINV4X3B9V7E 377
# /snl/abcd/raw-data/fmri/baseline/nback/sub-NDARINV4X3B9V7E/ses-baselineYear1Arm1/func/sub-NDARINV4X3B9V7E_ses-baselineYear1Arm1_task-nback_run-01_bold.nii
# missing ROIs!
# segmenting  sub-NDARINV51ZKXX4P 390
# ...

# %%
# filter: band pass in the 0.009-0.8 Hz band 
fmri_seg.band_pass_filt_fmri()
# Out:
# sub-NDARINVY6FE3R8A 11651
# sub-NDARINVY7DUFWF4 11653
# sub-NDARINVY81M9FZH 11655
# sub-NDARINVY8CPCJJ3 11657
# sub-NDARINVY98NL5JN 11659
# sub-NDARINVYA6B3A5N 11661
# sub-NDARINVYCMGF947 11664
# sub-NDARINVYGPAVGFJ 11671
# sub-NDARINVYM2Y11M1 11678
# sub-NDARINVYPL5XV35 11682
# sub-NDARINVYU8GX8G7 11688
# sub-NDARINVYW9MFMW8 11695
# sub-NDARINVYXRGTMYM 11699
# sub-NDARINVYZGRYL84 11705
# sub-NDARINVZ48R1346 11711
# sub-NDARINVZ5T7BWT5 11713
# sub-NDARINVZC64FXGK 11719
# sub-NDARINVZCCYZY0V 11721
# sub-NDARINVZCG5V8NV 11723
# sub-NDARINVZDA1D94K 11727
# sub-NDARINVZH7LD600 11733
# sub-NDARINVZJYGP0WE 11735
# sub-NDARINVZLEFF9ZA 11737
# sub-NDARINVZTFAZ4PF 11748
# sub-NDARINVZZ35KHXP 11750
# sub-NDARINVZZ4XNM65 11752
# sub-NDARINVYDMW8MYL 12256
# sub-NDARINVYDMW8MYL 12257
# sub-NDARINVYDTVRPWV 12258
# sub-NDARINVYDTVRPWV 12259
# sub-NDARINVYLTE2PT9 12260
# sub-NDARINVYLTE2PT9 12261
# sub-NDARINVYRZULCBY 12262
# sub-NDARINVYRZULCBY 12263
# sub-NDARINVYTKHPZDU 12264
# ...

# %%
np.savetxt('/home/acamassa/ABCD/task_Segerrors.txt', error, fmt='%s')

# %%
print(len(error))
# Out:
# 229
