# %%
from src.Labels import Labels
from src.utils import get_sig_rois

# %% [markdown]
# # DSM5

# %%
# Get dataframes for each disorder
labels = Labels(instrument="cbcl", disorder_type="dsm")
adhd = labels.adhd_dsm_df
anx = labels.anx_dsm_df
conduct = labels.conduct_dsm_df
depr = labels.depr_dsm_df
opposit = labels.opposit_dsm_df
somatic = labels.somatic_dsm_df

# %%
labels.metadata_df
# Out:
#                 sex  age hand
# NDARINV02UVMTY7   F  130    R
# NDARINV02WP3TP6   M  114    R
# NDARINV007W6H7B   M  126    R
# NDARINV00J52GPG   M  110    R
# NDARINV019DXLU4   F  132    R
# ...              ..  ...  ...
# NDARINVZWRJXNHE   F  110    R
# NDARINVZX24TGXN   M  114    R
# NDARINVZXKWKTC7   F  121    R
# NDARINVXLXL2EKK   F  108    R
# NDARINVZYC44GB8   M  131    R
#
# [11865 rows x 3 columns]

# %% [markdown]
# ## ADHD

# %%
vols, stats = get_sig_rois(adhd)
vols
# Out:
# ADHD
# ----------
# # control: 		 1156
# # disorder: 		 266
# # different regions: 	 8
#                          feature   p_value
# 2                  4th ventricle  0.004817
# 3               left hippocampus  0.006778
# 5              right hippocampus  0.011706
# 0   left cerebellum white matter  0.015033
# 4  right cerebellum white matter  0.021474
# 1                   left caudate  0.025531
# 6           right accumbens area  0.039048
# 7             ctx-rh-postcentral  0.045560

# %%
# for f in vols["feature"]:
stats.plot_hist("4th ventricle", save=True)

# %% [markdown]
# ## Anxiety

# %%
vols, stats = get_sig_rois(anx)
vols
# Out:
# ANXDISORD
# ----------
# # control: 		 1156
# # disorder: 		 301
# # different regions: 	 1
#                    feature   p_value
# 0  ctx-rh-lateraloccipital  0.013958

# %% [markdown]
# ## Conduct disorder

# %%
vols, stats = get_sig_rois(conduct)
vols
# Out:
# CONDUCT
# ----------
# # control: 		 1156
# # disorder: 		 260
# # different regions: 	 78
#                        feature   p_value
# 2         left cerebral cortex  0.000005
# 10            left hippocampus  0.000005
# 16       right cerebral cortex  0.000008
# 21           right hippocampus  0.000008
# 50        ctx-lh-supramarginal  0.000014
# ..                         ...       ...
# 33              ctx-lh-lingual  0.041281
# 5       left cerebellum cortex  0.045694
# 34  ctx-lh-medialorbitofrontal  0.047899
# 55               ctx-rh-cuneus  0.048716
# 66   ctx-rh-posteriorcingulate  0.049108
#
# [78 rows x 2 columns]

# %% [markdown]
# ## Depression

# %%
vols, stats = get_sig_rois(depr)
vols
# Out:
# DEPRESS
# ----------
# # control: 		 1156
# # disorder: 		 274
# # different regions: 	 19
#                           feature   p_value
# 15             ctx-rh-postcentral  0.000244
# 12             ctx-lh-postcentral  0.000851
# 6   right cerebellum white matter  0.004310
# 16              ctx-rh-precentral  0.012376
# 17        ctx-rh-superiortemporal  0.015992
# 18           ctx-rh-supramarginal  0.016068
# 13              ctx-lh-precentral  0.016420
# 4                left hippocampus  0.017547
# 3                      brain-stem  0.017863
# 0            left cerebral cortex  0.018393
# 8                right ventral DC  0.018791
# 5           right cerebral cortex  0.018805
# 1    left cerebellum white matter  0.021446
# 2                    left caudate  0.024940
# 10         ctx-lh-parahippocampal  0.036708
# 7                  right thalamus  0.036819
# 9         ctx-lh-inferiorparietal  0.040649
# 11             ctx-lh-paracentral  0.045294
# 14           ctx-lh-supramarginal  0.048383

# %% [markdown]
# ## Opposition

# %%
vols, stats = get_sig_rois(opposit)
vols
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-767940e0d33b> in <module>
# ----> 1 vols, stats = get_sig_rois(opposit)
#       2 vols
#
# /nadata/cnl/home/mwagner/projects/SynthSeg/abcd-code/analysis/src/utils.py in get_sig_rois(labels_df, run_qc)
#       4
#       5 def get_sig_rois(labels_df, run_qc=True):
# ----> 6     synthseg = SynthSeg(
#       7         subjects=labels_df.index,
#       8         run_qc=run_qc,
#
# /nadata/cnl/home/mwagner/projects/SynthSeg/abcd-code/analysis/src/SynthSeg.py in __init__(self, subjects, run_qc, run_qc_min_score, run_qc_max_failed_regions)
#      17             self.run_qc_min_score = run_qc_min_score
#      18             self.run_qc_max_failed_regions = run_qc_max_failed_regions
# ---> 19             self.qc_df = self.qc_df(
#      20                 self.run_qc_min_score, self.run_qc_max_failed_regions
#      21             )
#
# /nadata/cnl/home/mwagner/projects/SynthSeg/abcd-code/analysis/src/SynthSeg.py in qc_df(self, min_score, max_failed_regions)
#     111     ):
#     112         """Synthseg output df with only subjects that pass qc check."""
# --> 113         subjects_to_exclude = self.qc_subjects_to_exclude(
#     114             min_score=min_score, max_failed_regions=max_failed_regions
#     115         )
#
# /nadata/cnl/home/mwagner/projects/SynthSeg/abcd-code/analysis/src/SynthSeg.py in qc_subjects_to_exclude(self, min_score, max_failed_regions)
#      99     ):
#     100         """Subjects that did not pass qc check."""
# --> 101         failed_qc_regions = self.qc_regions_to_exclude(
#     102             min_score=min_score, max_failed_regions=max_failed_regions
#     103         )
#
# /nadata/cnl/home/mwagner/projects/SynthSeg/abcd-code/analysis/src/SynthSeg.py in qc_regions_to_exclude(self, min_score, max_failed_regions)
#      73         )
#      74         for index, row in self.qc_scores.iterrows():
# ---> 75             n_fails = (row < min_score).sum()
#      76
#      77             if n_fails >= max_failed_regions:
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11426                 name, axis=axis, level=level, skipna=skipna, min_count=min_count
#   11427             )
# > 11428         return self._reduce(
#   11429             func,
#   11430             name=name,
#
# /usr/lib/python3/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4247                 )
#    4248             with np.errstate(all="ignore"):
# -> 4249                 return op(delegate, skipna=skipna, **kwds)
#    4250
#    4251     def _reindex_indexer(self, new_index, indexer, copy):
#
# /usr/lib/python3/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# ~/.local/lib/python3.9/site-packages/numpy/core/_ufunc_config.py in __exit__(self, *exc_info)
#     434
#     435     def __exit__(self, *exc_info):
# --> 436         seterr(**self.oldstate)
#     437         if self.call is not _Unspecified:
#     438             seterrcall(self.oldcall)
#
# ~/.local/lib/python3.9/site-packages/numpy/core/_ufunc_config.py in seterr(all, divide, over, under, invalid)
#     109
#     110     pyvals = umath.geterrobj()
# --> 111     old = geterr()
#     112
#     113     if divide is None:
#
# ~/.local/lib/python3.9/site-packages/numpy/core/_ufunc_config.py in geterr()
#     175     val = (maskvalue >> SHIFT_UNDERFLOW) & mask
#     176     res['under'] = _errdict_rev[val]
# --> 177     val = (maskvalue >> SHIFT_INVALID) & mask
#     178     res['invalid'] = _errdict_rev[val]
#     179     return res
#
# KeyboardInterrupt:

# %% [markdown]
# ## Somatic

# %%
vols, stats = get_sig_rois(somatic)
vols
# Out:
# SOMATICPR
# ----------
# # control: 		 1156
# # disorder: 		 355
# # different regions: 	 3
#                             feature   p_value
# 0  right inferior lateral ventricle  0.021299
# 1     right cerebellum white matter  0.028094
# 2                    right pallidum  0.048255

# %% [markdown]
# # ASEBA

# %%
# Get dataframes for each disorder
labels = Labels(instrument="cbcl", disorder_type="aseba")
anxdep = labels.anxdep_aseba_df
withdep = labels.withdep_aseba_df
somatic = labels.somatic_aseba_df
social = labels.social_aseba_df
thought = labels.thought_aseba_df
attent = labels.attent_aseba_df
rulebreak = labels.rulebreak_aseba_df
aggro = labels.aggro_aseba_df

# %% [markdown]
# ## Anxious/Depressed

# %%
vols, stats = get_sig_rois(anxdep)
vols
# Out:
# ANXDEP
# ----------
# # control: 		 814
# # disorder: 		 261
# # different regions: 	 56
#                             feature   p_value
# 27               ctx-lh-postcentral  0.001239
# 7                     4th ventricle  0.001279
# 47               ctx-rh-postcentral  0.001608
# 39          ctx-rh-inferiorparietal  0.001679
# 35        ctx-lh-transversetemporal  0.002002
# 32             ctx-lh-supramarginal  0.002736
# 22          ctx-lh-inferiorparietal  0.003119
# 31          ctx-lh-superiortemporal  0.003331
# 14    right cerebellum white matter  0.005736
# 55                    ctx-rh-insula  0.005930
# 48        ctx-rh-posteriorcingulate  0.006399
# 44           ctx-rh-parahippocampal  0.007413
# 36                    ctx-lh-insula  0.007982
# 50  ctx-rh-rostralanteriorcingulate  0.008205
# 11              left accumbens area  0.008382
# 37   ctx-rh-caudalanteriorcingulate  0.008550
# 25           ctx-lh-parahippocampal  0.008803
# 16                   right pallidum  0.010313
# 20                ctx-lh-entorhinal  0.010444
# 45               ctx-rh-paracentral  0.010682
# 38                ctx-rh-entorhinal  0.012507
# 49                ctx-rh-precentral  0.012850
# 8                        brain-stem  0.013353
# 41          ctx-rh-isthmuscingulate  0.013397
# 46             ctx-rh-parsorbitalis  0.013767
# 34              ctx-lh-temporalpole  0.013964
# 3      left cerebellum white matter  0.013988
# 1        left cerebral white matter  0.015672
# 19                 right ventral DC  0.015779
# 17                   right amygdala  0.015937
# 21                  ctx-lh-fusiform  0.016662
# 54               ctx-rh-frontalpole  0.017610
# 40          ctx-rh-inferiortemporal  0.017844
# 13      right cerebral white matter  0.018123
# 29                 ctx-lh-precuneus  0.019205
# 12                  left ventral DC  0.020413
# 0                total intracranial  0.020556
# 53             ctx-rh-supramarginal  0.020678
# 23          ctx-lh-isthmuscingulate  0.029650
# 18             right accumbens area  0.030553
# 52          ctx-rh-superiortemporal  0.030760
# 6                     left pallidum  0.031968
# 9                     left amygdala  0.032998
# 33               ctx-lh-frontalpole  0.034078
# 5                      left putamen  0.034460
# 28                ctx-lh-precentral  0.034740
# 4                     left thalamus  0.036970
# 10                              csf  0.037451
# 26               ctx-lh-paracentral  0.037460
# 42      ctx-rh-lateralorbitofrontal  0.039008
# 51          ctx-rh-superiorparietal  0.041760
# 30  ctx-lh-rostralanteriorcingulate  0.042561
# 43                   ctx-rh-lingual  0.042904
# 15                   right thalamus  0.043684
# 24      ctx-lh-lateralorbitofrontal  0.045463
# 2              left cerebral cortex  0.049645

# %% [markdown]
# ## Withdrawn/Depressed

# %%
vols, stats = get_sig_rois(withdep)
vols
# Out:
# WITHDEP
# ----------
# # control: 		 814
# # disorder: 		 245
# # different regions: 	 1
#                    feature   p_value
# 0  ctx-lh-inferiorparietal  0.027855

# %% [markdown]
# ## Somatic

# %%
vols, stats = get_sig_rois(somatic)
vols
# Out:
# SOMATIC
# ----------
# # control: 		 814
# # disorder: 		 259
# # different regions: 	 22
#                           feature   p_value
# 10  right cerebellum white matter  0.000534
# 15             ctx-lh-postcentral  0.001362
# 2    left cerebellum white matter  0.001915
# 13           right accumbens area  0.005988
# 6                      brain-stem  0.007270
# 14               right ventral DC  0.011164
# 7             left accumbens area  0.013379
# 3          left cerebellum cortex  0.013930
# 5                   left pallidum  0.014434
# 21             ctx-rh-postcentral  0.016171
# 1            left cerebral cortex  0.018815
# 16              ctx-lh-precentral  0.020937
# 9           right cerebral cortex  0.020966
# 17    ctx-lh-rostralmiddlefrontal  0.023575
# 11        right cerebellum cortex  0.024546
# 12                 right pallidum  0.027169
# 8                 left ventral DC  0.027834
# 18        ctx-lh-superiortemporal  0.032954
# 19           ctx-lh-supramarginal  0.034633
# 4                    left caudate  0.037756
# 0              total intracranial  0.041761
# 20        ctx-rh-inferiorparietal  0.044793

# %% [markdown]
# ## Social

# %%
vols, stats = get_sig_rois(social)
vols
# Out:
# SOCIAL
# ----------
# # control: 		 814
# # disorder: 		 153
# # different regions: 	 36
#                           feature   p_value
# 14  right cerebellum white matter  0.000240
# 20           right accumbens area  0.000674
# 3          left cerebellum cortex  0.001240
# 8                      brain-stem  0.001379
# 2    left cerebellum white matter  0.001404
# 24             ctx-lh-postcentral  0.001662
# 11            left accumbens area  0.002612
# 10                  left amygdala  0.003641
# 33             ctx-rh-postcentral  0.004319
# 34              ctx-rh-precentral  0.004487
# 5                    left caudate  0.004551
# 15        right cerebellum cortex  0.004623
# 26               ctx-lh-precuneus  0.005973
# 21               right ventral DC  0.007710
# 18                 right pallidum  0.007770
# 7                   left pallidum  0.008379
# 12                left ventral DC  0.009263
# 1            left cerebral cortex  0.011616
# 16                  right caudate  0.011800
# 17                  right putamen  0.012596
# 28           ctx-lh-supramarginal  0.013760
# 35        ctx-rh-superiorparietal  0.014943
# 6                    left putamen  0.015111
# 13          right cerebral cortex  0.020123
# 19                 right amygdala  0.022774
# 27        ctx-lh-superiorparietal  0.024935
# 29                  ctx-lh-insula  0.025753
# 9                left hippocampus  0.028462
# 30                ctx-rh-fusiform  0.029412
# 4                   left thalamus  0.031119
# 31        ctx-rh-inferiorparietal  0.035224
# 22                ctx-lh-fusiform  0.035422
# 23        ctx-lh-inferiorparietal  0.037561
# 32             ctx-rh-paracentral  0.043157
# 0              total intracranial  0.043283
# 25              ctx-lh-precentral  0.046725

# %% [markdown]
# ## Thought

# %%
vols, stats = get_sig_rois(thought)
vols
# Out:
# THOUGHT
# ----------
# # control: 		 814
# # disorder: 		 377
# # different regions: 	 0
# Empty DataFrame
# Columns: [feature, p_value]
# Index: []

# %% [markdown]
# ## Rulebreaking

# %%
vols, stats = get_sig_rois(rulebreak)
vols
# Out:
# RULEBREAK
# ----------
# # control: 		 814
# # disorder: 		 215
# # different regions: 	 46
#                             feature   p_value
# 3      left cerebellum white matter  0.000460
# 12    right cerebellum white matter  0.000652
# 11            right cerebral cortex  0.000914
# 2              left cerebral cortex  0.001053
# 8                  left hippocampus  0.001153
# 5                      left caudate  0.001586
# 32             ctx-lh-supramarginal  0.001658
# 14                    right caudate  0.002418
# 41                ctx-rh-precentral  0.002667
# 34       ctx-rh-caudalmiddlefrontal  0.002699
# 15                right hippocampus  0.003044
# 36          ctx-rh-inferiorparietal  0.004038
# 0                total intracranial  0.005369
# 22      ctx-lh-lateralorbitofrontal  0.006393
# 27                 ctx-lh-precuneus  0.006706
# 37          ctx-rh-inferiortemporal  0.006884
# 45             ctx-rh-supramarginal  0.006886
# 26                ctx-lh-precentral  0.007146
# 44          ctx-rh-superiorparietal  0.007281
# 30          ctx-lh-superiorparietal  0.007495
# 17             right accumbens area  0.007834
# 40               ctx-rh-postcentral  0.008746
# 6                     4th ventricle  0.010174
# 16                   right amygdala  0.010361
# 1        left cerebral white matter  0.011861
# 28      ctx-lh-rostralmiddlefrontal  0.013579
# 25               ctx-lh-postcentral  0.014441
# 31          ctx-lh-superiortemporal  0.016298
# 20          ctx-lh-inferiorparietal  0.016323
# 39            ctx-rh-middletemporal  0.017315
# 10      right cerebral white matter  0.018786
# 24             ctx-lh-parsorbitalis  0.019167
# 18                 right ventral DC  0.020058
# 9                   left ventral DC  0.021129
# 42  ctx-rh-rostralanteriorcingulate  0.022416
# 21          ctx-lh-inferiortemporal  0.024215
# 7                        brain-stem  0.024262
# 43      ctx-rh-rostralmiddlefrontal  0.026246
# 13                   right thalamus  0.026613
# 29           ctx-lh-superiorfrontal  0.033056
# 4                     left thalamus  0.039757
# 35                  ctx-rh-fusiform  0.040693
# 19       ctx-lh-caudalmiddlefrontal  0.041612
# 33                    ctx-lh-insula  0.045007
# 38      ctx-rh-lateralorbitofrontal  0.046238
# 23           ctx-lh-parahippocampal  0.049796

# %% [markdown]
# ## Aggressive

# %%
vols, stats = get_sig_rois(aggro)
vols
# Out:
# AGGRESSIVE
# ----------
# # control: 		 814
# # disorder: 		 212
# # different regions: 	 21
#                           feature   p_value
# 6                left hippocampus  0.001982
# 9   right cerebellum white matter  0.005472
# 2    left cerebellum white matter  0.006425
# 1            left cerebral cortex  0.009371
# 8           right cerebral cortex  0.010567
# 12        ctx-lh-inferiorparietal  0.011750
# 18              ctx-rh-precentral  0.023061
# 3          left cerebellum cortex  0.025984
# 16        ctx-rh-inferiorparietal  0.026430
# 4                   left thalamus  0.028291
# 19        ctx-rh-superiorparietal  0.028721
# 14           ctx-lh-supramarginal  0.029394
# 15     ctx-rh-caudalmiddlefrontal  0.029918
# 13        ctx-lh-superiortemporal  0.030820
# 17        ctx-rh-inferiortemporal  0.033041
# 0              total intracranial  0.033675
# 20           ctx-rh-supramarginal  0.036788
# 10                 right thalamus  0.036824
# 5                      brain-stem  0.037036
# 11              right hippocampus  0.037341
# 7                   left amygdala  0.046727

# %% [markdown]
# ## Attention

# %%
vols, stats = get_sig_rois(attent)
vols
# Out:
# ATTENTION
# ----------
# # control: 		 814
# # disorder: 		 254
# # different regions: 	 84
#                           feature   p_value
# 17  right cerebellum white matter  0.000007
# 3    left cerebellum white matter  0.000030
# 10                     brain-stem  0.000411
# 36         ctx-lh-parahippocampal  0.000443
# 4          left cerebellum cortex  0.000690
# ..                            ...       ...
# 74               ctx-rh-precuneus  0.041959
# 22              right hippocampus  0.043159
# 46        ctx-lh-superiorparietal  0.043182
# 64          ctx-rh-middletemporal  0.043881
# 66             ctx-rh-paracentral  0.047011
#
# [84 rows x 2 columns]
